# %%
import pandas as pd
import numpy as np

# %%
# abrindo o arquivo .csv
cvd = pd.read_csv('C:/Data/COVID-19-global-data.csv') # 286770 8 coluns 
cvd
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 286765    2023-04-22           ZW     Zimbabwe       AFRO          2
# 286766    2023-04-23           ZW     Zimbabwe       AFRO          5
# 286767    2023-04-24           ZW     Zimbabwe       AFRO          2
# 286768    2023-04-25           ZW     Zimbabwe       AFRO          0
# 286769    2023-04-26           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
# ajustando a linha máxima permitida pelo pandas em no máximo 200
pd.options.display.max_rows = 200
cvd
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 286765    2023-04-22           ZW     Zimbabwe       AFRO          2
# 286766    2023-04-23           ZW     Zimbabwe       AFRO          5
# 286767    2023-04-24           ZW     Zimbabwe       AFRO          2
# 286768    2023-04-25           ZW     Zimbabwe       AFRO          0
# 286769    2023-04-26           ZW     Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# ...

# %%
# exibindo o tipo dados das colunas
cvd.dtypes
# Out:
# Date_reported        object
# Country_code         object
# Country              object
# WHO_region           object
# New_cases             int64
# Cumulative_cases      int64
# New_deaths            int64
# Cumulative_deaths     int64
# dtype: object

# %%
# visualizando as primeiras 15 linhas
cvd.head(15)
# Out:
#    Date_reported Country_code      Country WHO_region  New_cases  \
# 0     2020-01-03           AF  Afghanistan       EMRO          0
# 1     2020-01-04           AF  Afghanistan       EMRO          0
# 2     2020-01-05           AF  Afghanistan       EMRO          0
# 3     2020-01-06           AF  Afghanistan       EMRO          0
# 4     2020-01-07           AF  Afghanistan       EMRO          0
# 5     2020-01-08           AF  Afghanistan       EMRO          0
# 6     2020-01-09           AF  Afghanistan       EMRO          0
# 7     2020-01-10           AF  Afghanistan       EMRO          0
# 8     2020-01-11           AF  Afghanistan       EMRO          0
# 9     2020-01-12           AF  Afghanistan       EMRO          0
# 10    2020-01-13           AF  Afghanistan       EMRO          0
# 11    2020-01-14           AF  Afghanistan       EMRO          0
# 12    2020-01-15           AF  Afghanistan       EMRO          0
# ...

# %%
# visualizando as últimas 10 linhas
cvd.tail(10)
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 286760    2023-04-17           ZW  Zimbabwe       AFRO          3
# 286761    2023-04-18           ZW  Zimbabwe       AFRO          0
# 286762    2023-04-19           ZW  Zimbabwe       AFRO          6
# 286763    2023-04-20           ZW  Zimbabwe       AFRO          4
# 286764    2023-04-21           ZW  Zimbabwe       AFRO          7
# 286765    2023-04-22           ZW  Zimbabwe       AFRO          2
# 286766    2023-04-23           ZW  Zimbabwe       AFRO          5
# 286767    2023-04-24           ZW  Zimbabwe       AFRO          2
# 286768    2023-04-25           ZW  Zimbabwe       AFRO          0
# 286769    2023-04-26           ZW  Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 286760            264613           0               5684
# 286761            264613           0               5684
# 286762            264619           0               5684
# ...

# %%
# retornando informações sobre as linhas
cvd.index
# Out:
# RangeIndex(start=0, stop=286770, step=1)

# %%
# retornando as colunas do arquivo como Series
col = pd.Series(cvd.columns)
col
# Out:
# 0        Date_reported
# 1         Country_code
# 2              Country
# 3           WHO_region
# 4            New_cases
# 5     Cumulative_cases
# 6           New_deaths
# 7    Cumulative_deaths
# dtype: object

# %%
# retornando as colunas do arquivo como DataFrame
col = pd.DataFrame(cvd.columns)
col
# Out:
#                    0
# 0      Date_reported
# 1       Country_code
# 2            Country
# 3         WHO_region
# 4          New_cases
# 5   Cumulative_cases
# 6         New_deaths
# 7  Cumulative_deaths

# %%
# convertento o arquivo para um Array
cvd.to_numpy()
# Out:
# array([['2020-01-03', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-04', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ['2020-01-05', 'AF', 'Afghanistan', ..., 0, 0, 0],
#        ...,
#        ['2023-04-24', 'ZW', 'Zimbabwe', ..., 264639, 0, 5685],
#        ['2023-04-25', 'ZW', 'Zimbabwe', ..., 264639, 0, 5685],
#        ['2023-04-26', 'ZW', 'Zimbabwe', ..., 264639, 0, 5685]],
#       dtype=object)

# %%
# retornando um resumo estatístico
cvd.describe()
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  2.867700e+05      2.867700e+05  286770.000000       2.867700e+05
# mean   2.665810e+03      1.250508e+06      24.114398       1.663237e+04
# std    3.905500e+04      5.859306e+06     144.649623       7.126501e+04
# min   -8.261000e+03      0.000000e+00   -3520.000000       0.000000e+00
# 25%    0.000000e+00      1.499000e+03       0.000000       1.300000e+01
# 50%    1.100000e+01      2.939400e+04       0.000000       3.220000e+02
# 75%    3.520000e+02      3.413030e+05       4.000000       4.997000e+03
# max    6.966046e+06      1.030815e+08   11447.000000       1.121819e+06

# %%
# transpondo os dados, linha para coluna e vice versa
cvd.T
# Out:
#                         0            1            2            3       \
# Date_reported       2020-01-03   2020-01-04   2020-01-05   2020-01-06
# Country_code                AF           AF           AF           AF
# Country            Afghanistan  Afghanistan  Afghanistan  Afghanistan
# WHO_region                EMRO         EMRO         EMRO         EMRO
# New_cases                    0            0            0            0
# Cumulative_cases             0            0            0            0
# New_deaths                   0            0            0            0
# Cumulative_deaths            0            0            0            0
#
#                         4            5            6            7       \
# Date_reported       2020-01-07   2020-01-08   2020-01-09   2020-01-10
# Country_code                AF           AF           AF           AF
# Country            Afghanistan  Afghanistan  Afghanistan  Afghanistan
# ...

# %%
# classifica pela linha ou coluna, ordem crescente ou decrescente
cvd.sort_index(axis=0, ascending=False)
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 286769    2023-04-26           ZW     Zimbabwe       AFRO          0
# 286768    2023-04-25           ZW     Zimbabwe       AFRO          0
# 286767    2023-04-24           ZW     Zimbabwe       AFRO          2
# 286766    2023-04-23           ZW     Zimbabwe       AFRO          5
# 286765    2023-04-22           ZW     Zimbabwe       AFRO          2
# ...              ...          ...          ...        ...        ...
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 0         2020-01-03           AF  Afghanistan       EMRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 286769            264639           0               5685
# ...

# %%
# classificando os dados pela coluna New_cases ordenando do menor para o maior
cvd.sort_values(by="New_cases", ascending=True)
# Out:
#        Date_reported Country_code  Country WHO_region  New_cases  \
# 72848     2020-09-07           EC  Ecuador       AMRO      -8261
# 72725     2020-05-07           EC  Ecuador       AMRO      -2461
# 72727     2020-05-09           EC  Ecuador       AMRO      -1480
# 161435    2021-05-22           YT  Mayotte       AFRO       -875
# 117207    2022-11-15           IN    India      SEARO       -749
# ...              ...          ...      ...        ...        ...
# 51906     2022-12-24           CN    China       WPRO    5669864
# 51902     2022-12-20           CN    China       WPRO    5905312
# 51905     2022-12-23           CN    China       WPRO    6327801
# 51903     2022-12-21           CN    China       WPRO    6434648
# 51904     2022-12-22           CN    China       WPRO    6966046
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 72848             109784        3800              10524
# 72725              29420          49               1618
# ...

# %%
cvd.sort_values(by="Cumulative_cases", ascending=True)
# Out:
#        Date_reported Country_code                   Country WHO_region  \
# 0         2020-01-03           AF               Afghanistan       EMRO
# 194183    2021-08-08           PW                     Palau       WPRO
# 194182    2021-08-07           PW                     Palau       WPRO
# 194181    2021-08-06           PW                     Palau       WPRO
# 194180    2021-08-05           PW                     Palau       WPRO
# ...              ...          ...                       ...        ...
# 274665    2023-04-22           US  United States of America       AMRO
# 274666    2023-04-23           US  United States of America       AMRO
# 274667    2023-04-24           US  United States of America       AMRO
# 274668    2023-04-25           US  United States of America       AMRO
# 274669    2023-04-26           US  United States of America       AMRO
#
#         New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# ...

# %%
# selecionando uma única colunas
cvd['New_cases']

# outra forma
#print(cvd.New_cases)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 286765    2
# 286766    5
# 286767    2
# 286768    0
# 286769    0
# Name: New_cases, Length: 286770, dtype: int64

# %%
# retornando o registro indice 1 para indice 9
cvd[1:9]
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
# 5    2020-01-08           AF  Afghanistan       EMRO          0
# 6    2020-01-09           AF  Afghanistan       EMRO          0
# 7    2020-01-10           AF  Afghanistan       EMRO          0
# 8    2020-01-11           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0
# 5                 0           0                  0
# 6                 0           0                  0
# ...

# %%
# retornando a coluna 'Date_reported' do indice 0 á 9 como Série
pd.Series(cvd['Date_reported'][0:10])
# Out:
# 0    2020-01-03
# 1    2020-01-04
# 2    2020-01-05
# 3    2020-01-06
# 4    2020-01-07
# 5    2020-01-08
# 6    2020-01-09
# 7    2020-01-10
# 8    2020-01-11
# 9    2020-01-12
# Name: Date_reported, dtype: object

# %%
# retornando a coluna 'Date_reported' do indice 0 ao 9 como DataFrame
pd.DataFrame(cvd['Date_reported'][0:10])
# Out:
#   Date_reported
# 0    2020-01-03
# 1    2020-01-04
# 2    2020-01-05
# 3    2020-01-06
# 4    2020-01-07
# 5    2020-01-08
# 6    2020-01-09
# 7    2020-01-10
# 8    2020-01-11
# 9    2020-01-12

# %%
# retornando 4 colunas com números de linhas de indice 0 á 100
cvd.loc[:,['Date_reported','Country_code','New_cases','New_deaths',]][0:100]
# Out:
#    Date_reported Country_code  New_cases  New_deaths
# 0     2020-01-03           AF          0           0
# 1     2020-01-04           AF          0           0
# 2     2020-01-05           AF          0           0
# 3     2020-01-06           AF          0           0
# 4     2020-01-07           AF          0           0
# 5     2020-01-08           AF          0           0
# 6     2020-01-09           AF          0           0
# 7     2020-01-10           AF          0           0
# 8     2020-01-11           AF          0           0
# 9     2020-01-12           AF          0           0
# 10    2020-01-13           AF          0           0
# 11    2020-01-14           AF          0           0
# 12    2020-01-15           AF          0           0
# 13    2020-01-16           AF          0           0
# 14    2020-01-17           AF          0           0
# 15    2020-01-18           AF          0           0
# 16    2020-01-19           AF          0           0
# ...

# %%
# exportando o arquivo modelado e filtrado
varDF = cvd.loc[:,['Date_reported','Country_code','New_cases','New_deaths',]][0:100]
varDF.to_csv("C:/Data/your_name.csv")

# %%
# reduzindo a quantidade de linhas
cvd.loc[0:7,["Date_reported","New_cases"]]
# Out:
#   Date_reported  New_cases
# 0    2020-01-03          0
# 1    2020-01-04          0
# 2    2020-01-05          0
# 3    2020-01-06          0
# 4    2020-01-07          0
# 5    2020-01-08          0
# 6    2020-01-09          0
# 7    2020-01-10          0

# %%
# ...Para obter um valor escalar:...
